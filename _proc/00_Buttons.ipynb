# %% [raw]
# ---
# description: Widgets for building data systems.
# output-file: buttons.html
# title: widgets
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Imports

# %% [markdown]
# ### Module Imports

# %% [markdown]
# ### Hidden Imports

# %% [markdown]
# ## Globals, Module wide

# %% [markdown]
# ## Functions

# %% [markdown]
# ## Widgets

# %% [markdown]
# ###    def FolderSelector( parent, initial_dir='/', CallBack_func = None ):

# %% [markdown]
# ### class Toggle:

# %%
#| echo: false
#| output: asis
show_doc(Toggle)
# Out:
# ---
#
# [source](https://github.com/lidar532/dswidgets/blob/main/dswidgets/Buttons.py#L11){target="_blank" style="float:right; font-size:smaller"}
#
# ### Toggle
#
# >      Toggle (initial_state=0, id='', on_name='Data is On', off_name='Data is
# >              Off', on_color='primary', off_color='danger', change_cb=None)
#
# A `panel` toggle button with customizable properties.  The button's name and
# color is set according to the state of the button. If a user call back `change_cb`
# is given, it will be called each time the button is toggled.  A list will be
# passed containing the `id` and the `state` of the button.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | initial_state | int | 0 | The initial button state upon creation. |
# | id | str |  | An identifier string. |
# | on_name | str | Data is On | Message displayed on the button when in ON state |
# | off_name | str | Data is Off | Message displayed on button when in Off state |
# | on_color | str | primary | Color when ON |
# | off_color | str | danger | Color when Off |
# | change_cb | NoneType | None | An optional user call back function called when toggled. |

# %%
#show_doc(toggle_button)

# %%
def my_cb( value ):
  debug_w.value = value

# %%
debug_w = pn.widgets.StaticText(name="Debug", value = 'not set')
tb0 = Toggle(id='b1', on_name='0 Data On', off_name='0 Data off', change_cb=my_cb)
tb1 = Toggle(id='b2', on_name='1 Data On', off_name='1 Data off', initial_state=1, change_cb=my_cb)

# %%
pn.Row(tb0.button, tb1.button, debug_w)
# Out:
# Row
#     [0] Button(button_type='danger', name='0 Data off')
#     [1] Button(button_type='primary', name='1 Data On')
#     [2] StaticText(name='Debug', value='not set')

# %%
tb0.state, tb1.state
# Out:
# (0, 0)
